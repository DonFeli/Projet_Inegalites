# %%
import pandas as pd

# %%
data = pd.read_csv('/Users/felita/Library/Mobile Documents/com~apple~CloudDocs/Documents/Programming/Jupyter/0. CNAM Projects/Projet_Inegalites/Data/taux-seropositivite.csv', sep=';')

# %%
data
# Out:
#                         Géodes - Santé publique France  \
# 0    Référentiel géographique : France par département
# 1                                                 Code
# 2                                                   01
# 3                                                   02
# 4                                                   03
# ..                                                 ...
# 101                                                974
# 102                                                975
# 103                                                976
# 104                                                977
# 105                                                978
#
#                                         \
# 0
# 1                              Libellé
# 2                                  Ain
# 3                                Aisne
# 4                               Allier
# ..                                 ...
# 101                            Réunion
# ...

# %%
data = data[2:]
data.columns = ['Code', 'Département', 'Taux de séropositivité']
