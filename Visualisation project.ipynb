# %%
import pandas as pd

# %% [markdown]
# ### Niveau de vie

# %%
data = pd.read_excel('/Users/felita/Library/Mobile Documents/com~apple~CloudDocs/Documents/Data/revenu.xlsx', 'DEP')

# %%
data
# Out:
#     Fichier Localisé Social et Fiscal (FiLoSoFi) - Année 2017  \
# 0    France métropolitaine, Martinique et La Réunio...
# 1    Mise en ligne le 16/06/2020       Géographie a...
# 2    ©Insee       Source(s) : Insee-DGFIP-Cnaf-Cnav...
# 3                                    Code géographique
# 4                                               CODGEO
# ..                                                 ...
# 98                                                  93
# 99                                                  94
# 100                                                 95
# 101                                                972
# 102                                                974
#
#                Unnamed: 1                 Unnamed: 2  \
# 0                     NaN                        NaN
# 1                     NaN                        NaN
# 2                     NaN                        NaN
# 3    Libellé géographique  Nombre de ménages fiscaux
# ...

# %% [markdown]
# - Virer les 4 premieres lignes vides

# %%
taux_pauvrete = data.iloc[3:, :]
taux_pauvrete
# Out:
#     Fichier Localisé Social et Fiscal (FiLoSoFi) - Année 2017  \
# 3                                    Code géographique
# 4                                               CODGEO
# 5                                                   01
# 6                                                   02
# 7                                                   03
# ..                                                 ...
# 98                                                  93
# 99                                                  94
# 100                                                 95
# 101                                                972
# 102                                                974
#
#                Unnamed: 1                 Unnamed: 2  \
# 3    Libellé géographique  Nombre de ménages fiscaux
# 4                  LIBGEO                NBMENFISC17
# 5                     Ain                     256670
# 6                   Aisne                     222104
# ...

# %% [markdown]
# - Selectionner colonnes **Code géographique** + **Libellé Géographique** + **Taux de Pauvreté Ensemble (%)**

# %%
taux_pauvrete = taux_pauvrete.iloc[:, [0, 1, 6]]

# %% [markdown]
# - Renommer les colonnes

# %%
taux_pauvrete.columns = ['Code', 'Département', 'Taux de pauvreté']
taux_pauvrete
# Out:
#                   Code           Département               Taux de pauvreté
# 3    Code géographique  Libellé géographique  Taux de pauvreté-Ensemble (%)
# 4               CODGEO                LIBGEO                         TP6017
# 5                   01                   Ain                           10.5
# 6                   02                 Aisne                           18.5
# 7                   03                Allier                           15.4
# ..                 ...                   ...                            ...
# 98                  93     Seine-Saint-Denis                           27.9
# 99                  94          Val-de-Marne                           16.3
# 100                 95            Val-d'Oise                           16.6
# 101                972            Martinique                           28.6
# 102                974            La Réunion                           38.3
#
# [100 rows x 3 columns]
