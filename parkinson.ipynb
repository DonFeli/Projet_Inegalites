# %%
import pandas as pd

# %%
data = pd.read_csv('/Users/felita/Library/Mobile Documents/com~apple~CloudDocs/Documents/Programming/Jupyter/0. CNAM Projects/Projet_Inegalites/Data/taux-prevalence-parkinson.csv', sep= ';')

# %%
data
# Out:
#                         Géodes - Santé publique France  \
# 0    Référentiel géographique : France par département
# 1                                                 Code
# 2                                                   01
# 3                                                   02
# 4                                                   03
# ..                                                 ...
# 101                                                974
# 102                                                975
# 103                                                976
# 104                                                977
# 105                                                978
#
#                                         \
# 0
# 1                              Libellé
# 2                                  Ain
# 3                                Aisne
# 4                               Allier
# ..                                 ...
# 101                            Réunion
# ...

# %%
data = data[2:]
data.columns = ['Code', 'Département', 'Taux de prévalence standardisé Parkinson']

# %%
data
# Out:
#     Code                        Département  \
# 2     01                                Ain
# 3     02                              Aisne
# 4     03                             Allier
# 5     04            Alpes-de-Haute-Provence
# 6     05                       Hautes-Alpes
# ..   ...                                ...
# 101  974                            Réunion
# 102  975  Miquelon-Langlade et Saint Pierre
# 103  976                            Mayotte
# 104  977                   Saint-Barthélemy
# 105  978                       Saint-Martin
#
#     Taux de prévalence standardisé Parkinson
# 2                                       2.56
# 3                                       2.35
# 4                                        2.4
# 5                                       2.29
# 6                                       2.59
# ..                                       ...
# 101                                     1.98
# 102                                      NaN
# ...
